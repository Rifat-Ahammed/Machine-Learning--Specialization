# %% [markdown]
# <a href="https://colab.research.google.com/github/Rifat-Ahammed/Machine-Learning--Specialization/blob/main/C1_W1_Lab02_Model_Representation_Soln.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')

# %%
# x_train is the input variable (size in 1000 square feet)
# y_train is the target (price in 1000s of dollars)
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f'x_train = {x_train}')
print(f'y_train = {y_train}')
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %% [markdown]
# ## Number of training examples m
#
# I will use `m` to denote the number of training examples. Numpy arrays have a`.shape` parameter. `x_train.shape` returns a python tuple with an entry for each dimension. `x_train.shape[0]` is the length of the array and number of examples as shown below.

# %%
# m is the number of trainig examples

print(f'x_train.shape = {x_train.shape}')
m = x_train.shape[0]
print(f'numner of training example is = {m}')
# Out:
# x_train.shape = (2,)
# numner of training example is = 2

# %% [markdown]
# ## Training example x_i, y_i
# I will use (x$^{(𝑖)}$
#  , y$^{(𝑖)}$
#  ) to denote the  𝑖𝑡ℎ
#   training example. Since Python is zero indexed, (x$^{(0)}$
#  , y$^{(0)}$
#  ) is (1.0, 300.0) and (x$^{(1)}$
#  , y$^{(1)}$
#  ) is (2.0, 500.0).
#
# To access a value in a Numpy array, one indexes the array with the desired offset. For example the syntax to access location zero of `x_train` is `x_train[0]`. Run the next code block below to get the  𝑖𝑡ℎ
#   training example.

# %%
i = 0 ## Change this to 1 to see (x^1, y^1)

x_i = x_train[i]
y_i = y_train[i]
print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(0), y^(0)) = (1.0, 300.0)

# %% [markdown]
# ## Plotting the data
# I can plot these two points using the `scatter()` function in the `matplotlib` library, as shown in the cell below.
#
# * The function arguments `marker` and `c` show the points as red crosses (the default is blue dots).
#
# I can use other functions in the `matplotlib` library to set the title and labels to display

# %%
# plot the data point
plt.scatter(x_train, y_train, marker='x', c='r')

#set the title
plt.title('Housing prices')

#set the y axis label
plt.ylabel("Price(in 1000s of dollars)")

# set the x axis label
plt.xlabel("Size(1000 sqft)")
plt.show()

# %% [markdown]
# ## Model function
#
# <img align="left" src="./images/C1_W1_L3_S1_model.png"     style=" width:380px; padding: 10px; " > As described in lecture, the model function for linear regression (which is a function that maps from `x` to `y`) is represented as
#
# $$ f_{w,b}(x^{(i)}) = wx^{(i)} + b \tag{1}$$
#
# The formula above is how you can represent straight lines - different values of $w$ and $b$ give you different straight lines on the plot. <br/>
#
# Let's try to get a better intuition for this through the code blocks below. Let's start with $w = 100$ and $b = 100$.
#
# **Note: We can come back to this cell to adjust the model's w and b parameters**

# %%
w = 100
b = 100
print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 100
# b: 100

# %% [markdown]
# Now, let's compute the value of $f_{w,b}(x^{(i)})$ for our two data points. I can explicitly write this out for each data point as -
#
# for $x^{(0)}$, `f_wb = w * x[0] + b`
#
# for $x^{(1)}$, `f_wb = w * x[1] + b`
#
# For a large number of data points, this can get unwieldy and repetitive. So instead, you can calculate the function output in a `for` loop as shown in the `compute_model_output` function below.
# > **Note**: The argument description `(ndarray (m,))` describes a Numpy n-dimensional array of shape (m,). `(scalar)` describes an argument without dimensions, just a magnitude.
# > **Note**: `np.zero(n)` will return a one-dimensional numpy array with $n$ entries

# %%
def compute_model_output(x, w, b):
  """
    Computes the prediction of a linear model
    Args:
      x (ndarray (m,)): Data, m examples
      w,b (scalar)    : model parameters
    Returns
      f_wb (ndarray (m,)): model prediction
    """

  m = x.shape[0]
  f_wb = np.zeros(m) #created an array as size as the `x_train` shape
  for i in range(m):
    f_wb[i] = w * x[i] + b
  return f_wb

# %%
from types import LambdaType
from matplotlib import markers
tmp_f_wb = compute_model_output(x_train, w, b)

# %% [markdown]
# ## Verify before plotting
#
# * Before calling plt.plot, check the shapes:

# %%
print(x_train.shape)
print(tmp_f_wb.shape)
print(tmp_f_wb)
# Out:
# (2,)
# (2,)
# [200. 300.]

# %%
#plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b', label="Our Predction")

#plot the data points
plt.scatter(x_train, y_train, marker='x', c='r', label='Actual Values')

# set the titel
plt.title('Housing Prices')

#set the y axis label
plt.ylabel("Price(in 1000s of dollars)")

# set the x axis label
plt.xlabel("Size(1000 sqft)")
plt.show()

# %% [markdown]
# As you can see, setting $w = 100$ and $b = 100$ does *not* result in a line that fits our data.
#
# ### Challenge
# Try experimenting with different values of $w$ and $b$. What should the values be for a line that fits our data?

# %% [markdown]
# ### Prediction
# Now that we have a model, we can use it to make our original prediction. Let's predict the price of a house with 1200 sqft. Since the units of $x$ are in 1000's of sqft, $x$ is 1.2.

# %%
w = 200
b = 100
x_i = 1.2
cost_12000sqft = w * x_i + b
print(f"cost of 12000 sqft house is: {cost_12000sqft} thousands dollars")
# Out:
# cost of 12000 sqft house is: 340.0 thousands dollars
